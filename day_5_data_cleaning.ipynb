# %% [markdown]
# # Data cleaning

# %% [markdown]
# ## creating a dataset

# %%
import pandas as pd
import numpy as np
data = {
    "Name":["Alice", "Bob", "Charlie", "David", None],
    "Age":[25, np.nan, 35, 40, 22],
    "Marks":[85, 60, np.nan, 90, 75],
    "City":["New York", "Los Angeles", None, "Chicago", "Boston"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name   Age  Marks         City
# 0    Alice  25.0   85.0     New York
# 1      Bob   NaN   60.0  Los Angeles
# 2  Charlie  35.0    NaN         None
# 3    David  40.0   90.0      Chicago
# 4     None  22.0   75.0       Boston

# %%
print(df.isnull().sum())  #checking missing values
# Out:
# Name     1
# Age      1
# Marks    1
# City     1
# dtype: int64

# %%
df_cleaned = df.dropna()  #dropping rows with missing values
print(df_cleaned)
# Out:
#     Name   Age  Marks      City
# 0  Alice  25.0   85.0  New York
# 3  David  40.0   90.0   Chicago

# %%
print(df.duplicated().sum())  #checking duplicates
# Out:
# 0

# %%
df = df.drop_duplicates() #dropping duplicates

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      float64
#  2   Marks   5 non-null      float64
#  3   City    5 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 292.0+ bytes
# None
#             Age      Marks
# count   5.00000   5.000000
# mean   30.50000  77.500000
# std     7.29726  11.456439
# min    22.00000  60.000000
# 25%    25.00000  75.000000
# 50%    30.50000  77.500000
# 75%    35.00000  85.000000
# max    40.00000  90.000000

# %%
print(df["Marks"].mean())
print(df["Age"].mean())
# Out:
# 77.5
# 30.5
