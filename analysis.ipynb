# %% [markdown]
# # EDA(exploratory data analysis)

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("../Data_project/data.csv")

# %% [markdown]
# ### Basic information

# %%
print("Shape:", df.shape) 
print("\nColumns:") 
print(df.columns)
# Out:
# Shape: (20, 8)
#
# Columns:
# Index(['EmployeeID', 'Name', 'Age', 'Gender', 'Department', 'Salary',
#        'Experience', 'City'],
#       dtype='object')

# %%
print("\nInfo:") 
print(df.info())
# Out:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  20 non-null     int64
#  1   Name        20 non-null     object
#  2   Age         20 non-null     int64
#  3   Gender      20 non-null     object
#  4   Department  20 non-null     object
#  5   Salary      20 non-null     int64
#  6   Experience  20 non-null     int64
#  7   City        20 non-null     object
# dtypes: int64(4), object(4)
# memory usage: 1.4+ KB
# None

# %% [markdown]
# ### Missing values

# %%
print("\nMissing Values:") 
print(df.isnull().sum())
# Out:
# Missing Values:
# EmployeeID    0
# Name          0
# Age           0
# Gender        0
# Department    0
# Salary        0
# Experience    0
# City          0
# dtype: int64

# %% [markdown]
# ### Summary statistics

# %%
print("\nSummary Statistics:") 
print(df.describe())
# Out:
# Summary Statistics:
#        EmployeeID        Age        Salary  Experience
# count    20.00000  20.000000     20.000000   20.000000
# mean    110.50000  32.800000  65350.000000    6.900000
# std       5.91608   6.143889  14747.970422    4.339537
# min     101.00000  24.000000  42000.000000    1.000000
# 25%     105.75000  28.000000  55750.000000    3.750000
# 50%     110.50000  31.500000  63500.000000    5.500000
# 75%     115.25000  37.250000  73500.000000   10.250000
# max     120.00000  45.000000  95000.000000   15.000000

# %% [markdown]
# ### Department count

# %%
print("\nDepartment Distribution:") 
print(df['Department'].value_counts())
# Out:
# Department Distribution:
# Department
# IT         5
# HR         5
# Finance    5
# Sales      5
# Name: count, dtype: int64

# %% [markdown]
# ### Salary distribution

# %%
plt.figure(figsize=(8,5)) 
sns.histplot(df['Salary'], kde=True) 
plt.title("Salary Distribution") 
plt.show()

# %% [markdown]
# ### Age distribution

# %%
plt.figure(figsize=(8,5)) 
sns.histplot(df['Age'], kde=True) 
plt.title("Age Distribution") 
plt.show()

# %% [markdown]
# ### Boxplot for salary

# %%
plt.figure(figsize=(8,5)) 
sns.boxplot(x=df['Salary']) 
plt.title("Salary Outliers") 
plt.show()

# %% [markdown]
# ### Correlation heatmap

# %%
plt.figure(figsize=(6,4)) 
sns.heatmap(df.corr(numeric_only=True), 
                        annot=True, 
                        cmap="coolwarm") 
plt.title("Correlation Heatmap") 
plt.show()

# %% [markdown]
# ### pair plot

# %%
sns.pairplot(df[['Age','Salary','Experience']]) 
plt.show()

# %% [markdown]
# ### Skewness

# %%
print("\nSkewness:") 
print(df[['Age','Salary','Experience']].skew())
# Out:
# Skewness:
# Age           0.441903
# Salary        0.378344
# Experience    0.509053
# dtype: float64

# %% [markdown]
# ### kurthosis

# %%
print("\nKurtosis:")
print(df[['Age','Salary','Experience']].kurtosis())
# Out:
# Kurtosis:
# Age          -0.891916
# Salary       -0.498538
# Experience   -1.019579
# dtype: float64
